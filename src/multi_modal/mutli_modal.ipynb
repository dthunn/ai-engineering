# %%
import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
easy_puzzle = [
    {"role": "user", "content":
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
openai = OpenAI()

response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 1/3

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# Interpretation:
# - Each volume has pages total thickness 2 cm.
# - Each cover (front and back) is 2 mm thick.
# - The volumes are placed side by side in order: first volume, then second volume.
# - A worm gnaws straight from the first page of the first volume to the last page of the second volume, moving perpendicular to the pages (i.e., through the covers and gaps between volumes as needed).
#
# Key idea: When books are on a shelf, the pages near the spine of a volume are adjacent to the pages near the spine of the neighboring volume only if the volumes are opened in a certain way. For a standard arrangement, the only material the worm must pass through from the very first page of the first volume to the very last page of the second volume is through:
# - the inner cover of the first volume,
# - the space between the two volumes (the air gap) if any,
# - the inner cover of the second volume,
# and possibly the outer surfaces if counted, but the problem typically assumes the worm goes straight from the first page of V1 to the last page of V2 through the shared boundary between the two volumes, which is the inner sides (the spines face inward to the shelf).
#
# However, a classic elegant solution notes a simpler path: The worm starts at the first page of the first volume (the page closest to the front cover when the book is closed and placed on a shelf with the front cover facing you) and ends at the last page of the second volume (the page closest to the back cover). If the two volumes are placed upright with their front covers facing you and the spines facing outward, the worm would traverse:
# - through the inside front cover of the first volume (2 mm),
# - through the air space between the two volumes (the gap between the inner faces of the volumes),
# - through the inside back cover of the second volume (2 mm).
#
# But note the problem gives no gap thickness between the volumes; the two volumes touch each other. In that case, the path from the first page of V1 to the last page of V2 goes through:
# - the inner cover of the first volume (2 mm),
# - the inner cover of the second volume (2 mm).
#
# Crucially, the worm does not need to go through any pages at all beyond the two inner covers, because the first page of V1 is adjacent to its inner cover, and the last page of V2 is adjacent to its inner cover. The portion of paper between the two volumes is actually the metal of the shelf? No, it’s the pages of the two volumes. But the worm’s path from the first page of V1 to the last page of V2, perpendicular to pages, would pass through:
# - the inner cover of V1 (2 mm),
# - the entire thickness that lies between the inner faces of the two volumes. When books are side by side and touching, that distance is zero, except for the covers themselves of the touching surfaces.
# - the inner cover of V2 (2 mm).
#
# Therefore total distance = thickness of inner cover of V1 + thickness of inner cover of V2 = 2 mm + 2 mm = 4 mm.
#
# Answer: 4 millimeters.

# %%
from langchain_openai import ChatOpenAI

tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# Here are a few quick ones — pick your favorite:
#
# 1) Why did the LLM engineering student stare at the loss curve all night? They heard "convergence" and thought it was a party.
#
# 2) How many LLM engineers does it take to change a lightbulb? None — that's a hardware problem. They'll just fine-tune the darkness away.
#
# 3) RuntimeWarning: Model refuses to generalize. Suggested fix: add more diverse data, lower the learning rate, and increase the student's coffee intake.

# %%
requests.get("http://localhost:11434/").content
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2
# Out:
# Feb 27 2026 02:29:01 - ERROR - generated.c:2302 - CHECK failed: mlx_array_item_float16_
# 2026/03/01 09:23:52 ERROR Failed to load MLX dynamic library symbols path=/Applications/Ollama.app/Contents/Resources/libmlxc.dylib
# 2026/03/01 09:23:52 WARN MLX dynamic library not available error="failed to load MLX dynamic library (searched: [/Applications/Ollama.app/Contents/Resources /Users/dylanthunn/Documents/python/ai-engineering/src/multi_modal/build/lib/ollama])"
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
ollama_url = "http://localhost:11434/v1"
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2
